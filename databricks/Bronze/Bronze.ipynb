# %% [markdown]
# # Loading Tables into Bronze layer

# %% [markdown]
# ## Loading Data from Just Join It service

# %%
df = spark.read.option("multiline", "true").json("s3://job-offers-data/raw/just_join_it/")
df.write.mode("overwrite").saveAsTable("`job-offers-warehouse`.bronze.justJoinIt_job_offers")
