# %% [markdown]
# # Initializing schemas and catalog

# %%
# %sql
CREATE CATALOG IF NOT EXISTS `job-offers-warehouse`;
CREATE SCHEMA IF NOT EXISTS `job-offers-warehouse`.bronze;
CREATE SCHEMA IF NOT EXISTS `job-offers-warehouse`.silver;
CREATE SCHEMA IF NOT EXISTS `job-offers-warehouse`.gold;
